# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt
import seaborn as sns 
import plotly.express as px
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
#  Step-1 Load Data Set

# %%
df= pd.read_csv('BigBasket Products.csv')

# %%
df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
#  Step-2 : Use head function to look for first 12 rows.

# %%
df.head(12)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
#
#                   category            sub_category              brand  \
# 0         Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# ...

# %% [markdown]
# Step 3: Get Description of the data in the DataFrame.

# %%
# Description of dataset

df.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %% [markdown]
# Step 4: Find Information about the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# We have 6 categorical columns
# We have 4 Numerical columns, including index(int)
# We have Null columns in dataset as well

# %% [markdown]
# Step 5: Find out Top & least sold products.

# %%
top_products = df['product'].value_counts().head(5)
least_products = df['product'].value_counts().tail(5)
print("Top 5 Products:", top_products)
print("Least 5 Products:", least_products)
# Out:
# Top 5 Products: product
# Turmeric Powder/Arisina Pudi          26
# Extra Virgin Olive Oil                15
# Cow Ghee/Tuppa                        14
# Soft Drink                            12
# Colorsilk Hair Colour With Keratin    12
# Name: count, dtype: int64
# Least 5 Products: product
# Pepper & Herb Salami Chicken                                     1
# Nutmeg Powder                                                    1
# Disney Mickey Mouse Plastic Kids Sipper Bottle - Coolest Dude    1
# Chocolates-Roasted Peanut Chocolate                              1
# Green Tea - Pure Original                                        1
# Name: count, dtype: int64

# %% [markdown]
# Step 6: Measuring discount on a certain item.

# %%
discount=df["market_price"]-df["sale_price"]
discount=round(discount/df["market_price"]*100,2)

discount_df = pd.DataFrame({"Product": df["product"],"Discount (%)": discount})
print(discount_df)
# Out:
#                                                  Product  Discount (%)
# 0                 Garlic Oil - Vegetarian Capsule 500 mg          0.00
# 1                                  Water Bottle - Orange          0.00
# 2                         Brass Angle Deep - Plain, No.2         52.40
# 3      Cereal Flip Lid Container/Storage Jar - Assort...         15.34
# 4                     Creme Soft Soap - For Hands & Body          0.00
# ...                                                  ...           ...
# 27550         Wottagirl! Perfume Spray - Heaven, Classic         20.00
# 27551                                           Rosemary         10.00
# 27552                       Peri-Peri Sweet Potato Chips          0.00
# 27553                          Green Tea - Pure Original         20.00
# 27554                     United Dreams Go Far Deodorant         44.99
#
# [27555 rows x 2 columns]

# %% [markdown]
# Step 7: Find out the Missing Values from the Dataset.

# %%
df.isnull().sum().sort_values()
# Out:
# index              0
# category           0
# sub_category       0
# market_price       0
# type               0
# product            1
# brand              1
# sale_price         6
# description      115
# rating          8636
# dtype: int64

# %%
#: Find out the Missing Values from the Dataset

df.isnull().sum().sum()
# Out:
# 8759

# %% [markdown]
# We have a Null column in Product
# We have a Null column in Brand
# We have 6 Null Columns in Sale_Price**
# We have 8636 Null Columns in Rating
# We have 115 Null columns in description
# Intotal 8759 Null columns

# %% [markdown]
# Step 8: Find out the outliers from the dataset according to the columns and fill them with the mean.

# %%
# column 'sale_price'
Q1 = df['sale_price'].quantile(0.25)
Q3 = df['sale_price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Replace outliers with mean
df['sale_price'] = np.where(
    (df['sale_price'] < lower_bound) | (df['sale_price'] > upper_bound),df['sale_price'].mean(),df['sale_price'])

# %%
# column 'market_price'
Q1 = df['market_price'].quantile(0.25)
Q3 = df['market_price'].quantile(0.75)
IQR = Q3 - Q1
lower_bound_m = Q1 - 1.5 * IQR
upper_bound_m = Q3 + 1.5 * IQR

# Replace outliers with mean
df['market_price'] = np.where(
    (df['market_price'] < lower_bound) | (df['market_price'] > upper_bound),df['market_price'].mean(),df['market_price'])

# %% [markdown]
# Step 9: Create Plots or visualizations.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size
sns.set(rc={"figure.figsize": (20, 7)})

# Check if 'category' exists and is not empty
if 'category' in df.columns and not df['category'].isnull().all():
    # Ensure 'category' is treated as a categorical column
    df['category'] = df['category'].astype('category')
    
    # Create the countplot with explicit data parameter
    ax = sns.countplot(data=df, x="category")
    
    # Add count labels to the bars
    for bars in ax.containers:
        ax.bar_label(bars, fmt='%d')

    # Rotate x-axis labels for readability
    plt.xticks(rotation=90)

    # Add title and labels
    plt.title("Count of Each Category", fontsize=16)
    plt.xlabel("Category", fontsize=14)
    plt.ylabel("Count", fontsize=14)

    # Show the plot
    plt.show()
else:
    print("Column 'category' is missing or has no valid data!")
